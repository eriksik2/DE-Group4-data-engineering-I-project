# %%
# import pandas, numpy, matplotlib, and seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %%
# import the data
df = pd.read_csv('love-data.csv')
df.head()
columns = ['Subreddit', 'Total Comments', 'Hate/Love']

# %%
# Create a barplot of the data
fig = plt.figure(figsize=(12, 6))
ax0 = fig.add_subplot(1, 1, 1)
ax0.bar(df['Subreddit'], df['Hate/Love'], color='blue')
ax0.set_xticklabels(df['Subreddit'], rotation=60)

plt.title('Love/Hate Comments in Subreddits')
plt.xlabel('Subreddit')
plt.ylabel('Love to Hate Ratio')
plt.show()
# Out:
# /tmp/ipykernel_233139/404410523.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax0.set_xticklabels(df['Subreddit'], rotation=60)
